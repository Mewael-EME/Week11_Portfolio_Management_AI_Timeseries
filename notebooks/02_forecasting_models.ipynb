# %%
import os, sys

# Go to project root (adjust path if needed)
os.chdir("..")  

# Add src folder to Python path
sys.path.append(os.path.abspath("src"))

# %%
from src.forecast_arima import train_arima

# ARIMA
arima_results = train_arima("data/adj_close_prices.csv")
print(arima_results)
# Out:
# C:\Users\Admin\Desktop\Online class 2017_18\KAIM\Week 11\portfolio_management_ai_timeseries\venv310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Admin\Desktop\Online class 2017_18\KAIM\Week 11\portfolio_management_ai_timeseries\venv310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Admin\Desktop\Online class 2017_18\KAIM\Week 11\portfolio_management_ai_timeseries\venv310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
from src.forecast_sarima import train_sarima

# SARIMA
sarima_results = train_sarima("data/adj_close_prices.csv")
print(sarima_results)
# Out:
# C:\Users\Admin\Desktop\Online class 2017_18\KAIM\Week 11\portfolio_management_ai_timeseries\venv310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Admin\Desktop\Online class 2017_18\KAIM\Week 11\portfolio_management_ai_timeseries\venv310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Admin\Desktop\Online class 2017_18\KAIM\Week 11\portfolio_management_ai_timeseries\venv310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
from src.forecast_lstm import train_lstm
# LSTM
lstm_results = train_lstm("data/adj_close_prices.csv")
print(lstm_results)
# Out:
# Epoch 1/20
# 65/65 [==============================] - 6s 40ms/step - loss: 0.0106
# Epoch 2/20
# 65/65 [==============================] - 3s 39ms/step - loss: 0.0020
# Epoch 3/20
# 65/65 [==============================] - 3s 39ms/step - loss: 0.0018
# Epoch 4/20
# 65/65 [==============================] - 3s 40ms/step - loss: 0.0018
# Epoch 5/20
# 65/65 [==============================] - 3s 45ms/step - loss: 0.0017
# Epoch 6/20
# 65/65 [==============================] - 3s 43ms/step - loss: 0.0015
# Epoch 7/20
# 65/65 [==============================] - 3s 42ms/step - loss: 0.0016
# Epoch 8/20
# 65/65 [==============================] - 3s 42ms/step - loss: 0.0014
# Epoch 9/20
# 65/65 [==============================] - 3s 49ms/step - loss: 0.0013
# Epoch 10/20
# 65/65 [==============================] - 3s 52ms/step - loss: 0.0013
# Epoch 11/20
# 65/65 [==============================] - 3s 53ms/step - loss: 0.0013
# Epoch 12/20
# ...
